# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

plt.style.use('dark_background')

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=46b5180765b557381492a6d9a78cd8af

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | nanakuli
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | progreso
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | bathsheba
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | cocobeach
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | ovsyanka
# Processing Record 16 of Set 1 | narsaq
# Processing Record 17 of Set 1 | gualeguay
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | erenhot
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | geraldton
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | asau
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | althofen
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | missoula
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | severo-kurilsk
# Processing Record 34 of Set 1 | lasa
# Processing Record 35 of Set 1 | el balyana
# City not found. Skipping...
# Processing Record 36 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | hals
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | iskateley
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | yumen
# Processing Record 43 of Set 1 | ureki
# Processing Record 44 of Set 1 | krasnoselkup
# Processing Record 45 of Set 1 | pangai
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | rawson
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | camabatela
# Processing Record 1 of Set 2 | bonavista
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | sobolevo
# Processing Record 4 of Set 2 | viru
# Processing Record 5 of Set 2 | panixtlahuaca
# City not found. Skipping...
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | tabas
# Processing Record 14 of Set 2 | manono
# Processing Record 15 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 2 | cervo
# Processing Record 19 of Set 2 | aksu
# Processing Record 20 of Set 2 | brigantine
# Processing Record 21 of Set 2 | kabanjahe
# Processing Record 22 of Set 2 | barstow
# Processing Record 23 of Set 2 | fairbanks
# Processing Record 24 of Set 2 | tual
# Processing Record 25 of Set 2 | tigil
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | cockburn town
# Processing Record 29 of Set 2 | newport
# Processing Record 30 of Set 2 | tessalit
# Processing Record 31 of Set 2 | kano
# Processing Record 32 of Set 2 | teguise
# Processing Record 33 of Set 2 | panjab
# Processing Record 34 of Set 2 | la ronge
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | gat
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | airai
# Processing Record 40 of Set 2 | najran
# Processing Record 41 of Set 2 | roald
# Processing Record 42 of Set 2 | ugoofaaru
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | inhambane
# Processing Record 45 of Set 2 | solnechnyy
# Processing Record 46 of Set 2 | mahibadhoo
# Processing Record 47 of Set 2 | lat yao
# Processing Record 48 of Set 2 | marsh harbour
# Processing Record 49 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | pyapon
# Processing Record 2 of Set 3 | lethem
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | nouadhibou
# Processing Record 5 of Set 3 | pedernales
# Processing Record 6 of Set 3 | east brainerd
# Processing Record 7 of Set 3 | flin flon
# Processing Record 8 of Set 3 | margate
# Processing Record 9 of Set 3 | torbay
# Processing Record 10 of Set 3 | burnie
# Processing Record 11 of Set 3 | malakal
# Processing Record 12 of Set 3 | listvyanskiy
# Processing Record 13 of Set 3 | beringovskiy
# Processing Record 14 of Set 3 | kiama
# Processing Record 15 of Set 3 | labuan
# Processing Record 16 of Set 3 | ningan
# City not found. Skipping...
# Processing Record 17 of Set 3 | gamba
# Processing Record 18 of Set 3 | kavieng
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | marawi
# Processing Record 21 of Set 3 | uhlove
# Processing Record 22 of Set 3 | chapais
# Processing Record 23 of Set 3 | cayenne
# Processing Record 24 of Set 3 | mehamn
# Processing Record 25 of Set 3 | yulara
# Processing Record 26 of Set 3 | batticaloa
# Processing Record 27 of Set 3 | vilyuysk
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | doha
# Processing Record 30 of Set 3 | milkovo
# Processing Record 31 of Set 3 | banda aceh
# Processing Record 32 of Set 3 | addi ugri
# City not found. Skipping...
# Processing Record 33 of Set 3 | kilindoni
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | grindavik
# Processing Record 36 of Set 3 | bubaque
# Processing Record 37 of Set 3 | zhezkazgan
# Processing Record 38 of Set 3 | ancud
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | chokurdakh
# Processing Record 41 of Set 3 | raudeberg
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | lavagna
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | vinh
# Processing Record 46 of Set 3 | bolpur
# Processing Record 47 of Set 3 | san patricio
# Processing Record 48 of Set 3 | kuusamo
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | sao miguel do araguaia
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | vila franca do campo
# Processing Record 3 of Set 4 | isangel
# Processing Record 4 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 4 | neka
# Processing Record 6 of Set 4 | miyoshi
# Processing Record 7 of Set 4 | dondo
# Processing Record 8 of Set 4 | nykoping
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | poum
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | chaozhou
# Processing Record 13 of Set 4 | qobustan
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | port blair
# Processing Record 16 of Set 4 | ongandjera
# Processing Record 17 of Set 4 | nenjiang
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | belmonte
# Processing Record 20 of Set 4 | honiara
# Processing Record 21 of Set 4 | touros
# Processing Record 22 of Set 4 | arinos
# Processing Record 23 of Set 4 | ilinskiy
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | chernyanka
# Processing Record 26 of Set 4 | vanavara
# Processing Record 27 of Set 4 | tupaciguara
# Processing Record 28 of Set 4 | busembatia
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | sinnamary
# Processing Record 31 of Set 4 | lorca
# Processing Record 32 of Set 4 | ponta delgada
# Processing Record 33 of Set 4 | marsa matruh
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 4 | kotdwara
# Processing Record 37 of Set 4 | antofagasta
# Processing Record 38 of Set 4 | cairns
# Processing Record 39 of Set 4 | pundaguitan
# Processing Record 40 of Set 4 | muros
# Processing Record 41 of Set 4 | upernavik
# Processing Record 42 of Set 4 | high level
# Processing Record 43 of Set 4 | faanui
# Processing Record 44 of Set 4 | samarai
# Processing Record 45 of Set 4 | camacha
# Processing Record 46 of Set 4 | verkhnyaya inta
# Processing Record 47 of Set 4 | formosa do rio preto
# Processing Record 48 of Set 4 | masvingo
# Processing Record 49 of Set 4 | sola
# Processing Record 50 of Set 4 | cabo san lucas
# Processing Record 1 of Set 5 | straldza
# City not found. Skipping...
# Processing Record 2 of Set 5 | eureka
# Processing Record 3 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 5 | beloha
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | kuytun
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | mezen
# Processing Record 10 of Set 5 | saldanha
# Processing Record 11 of Set 5 | broome
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | darnah
# Processing Record 14 of Set 5 | hovd
# Processing Record 15 of Set 5 | lewiston
# Processing Record 16 of Set 5 | kavaratti
# Processing Record 17 of Set 5 | nefteyugansk
# Processing Record 18 of Set 5 | le port
# Processing Record 19 of Set 5 | gravdal
# Processing Record 20 of Set 5 | inhuma
# Processing Record 21 of Set 5 | tuktoyaktuk
# Processing Record 22 of Set 5 | shestakovo
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | clifton
# Processing Record 26 of Set 5 | saint-leu
# Processing Record 27 of Set 5 | batyrevo
# Processing Record 28 of Set 5 | taltal
# Processing Record 29 of Set 5 | nioro
# Processing Record 30 of Set 5 | dongsheng
# Processing Record 31 of Set 5 | wonthaggi
# Processing Record 32 of Set 5 | port moresby
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | karratha
# Processing Record 35 of Set 5 | georgetown
# Processing Record 36 of Set 5 | bac lieu
# Processing Record 37 of Set 5 | lebanon
# Processing Record 38 of Set 5 | northam
# Processing Record 39 of Set 5 | labuhan
# Processing Record 40 of Set 5 | tautira
# Processing Record 41 of Set 5 | acapulco
# Processing Record 42 of Set 5 | hilo
# Processing Record 43 of Set 5 | kaeng khoi
# Processing Record 44 of Set 5 | dera bugti
# Processing Record 45 of Set 5 | banjar
# Processing Record 46 of Set 5 | emerald
# Processing Record 47 of Set 5 | sao filipe
# Processing Record 48 of Set 5 | boke
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | lishui
# Processing Record 1 of Set 6 | great yarmouth
# Processing Record 2 of Set 6 | dikson
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | kununurra
# Processing Record 5 of Set 6 | rensvik
# Processing Record 6 of Set 6 | ondjiva
# Processing Record 7 of Set 6 | carutapera
# Processing Record 8 of Set 6 | deputatskiy
# Processing Record 9 of Set 6 | solwezi
# Processing Record 10 of Set 6 | rio grande
# Processing Record 11 of Set 6 | palmares do sul
# Processing Record 12 of Set 6 | sur
# Processing Record 13 of Set 6 | rudnogorsk
# Processing Record 14 of Set 6 | south farmingdale
# Processing Record 15 of Set 6 | chuy
# Processing Record 16 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 6 | pacific grove
# Processing Record 18 of Set 6 | banmo
# City not found. Skipping...
# Processing Record 19 of Set 6 | haines junction
# Processing Record 20 of Set 6 | huautla
# Processing Record 21 of Set 6 | oxelosund
# Processing Record 22 of Set 6 | hambantota
# Processing Record 23 of Set 6 | ferrol
# Processing Record 24 of Set 6 | kotelnikovo
# Processing Record 25 of Set 6 | yeppoon
# Processing Record 26 of Set 6 | coffs harbour
# Processing Record 27 of Set 6 | te anau
# Processing Record 28 of Set 6 | arraial do cabo
# Processing Record 29 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 30 of Set 6 | codrington
# Processing Record 31 of Set 6 | moiyabana
# City not found. Skipping...
# Processing Record 32 of Set 6 | qaqortoq
# Processing Record 33 of Set 6 | alice springs
# Processing Record 34 of Set 6 | sogdiondon
# City not found. Skipping...
# Processing Record 35 of Set 6 | manoel urbano
# Processing Record 36 of Set 6 | kronach
# Processing Record 37 of Set 6 | qui nhon
# Processing Record 38 of Set 6 | woodstock
# Processing Record 39 of Set 6 | vila do maio
# Processing Record 40 of Set 6 | pemangkat
# Processing Record 41 of Set 6 | broken hill
# Processing Record 42 of Set 6 | bethanien
# Processing Record 43 of Set 6 | charters towers
# Processing Record 44 of Set 6 | saint-denis
# Processing Record 45 of Set 6 | rehoboth
# Processing Record 46 of Set 6 | havre-saint-pierre
# Processing Record 47 of Set 6 | snezhnogorsk
# Processing Record 48 of Set 6 | the valley
# Processing Record 49 of Set 6 | agirish
# Processing Record 50 of Set 6 | faya
# Processing Record 1 of Set 7 | sao joao da barra
# Processing Record 2 of Set 7 | umba
# Processing Record 3 of Set 7 | meulaboh
# Processing Record 4 of Set 7 | bushehr
# Processing Record 5 of Set 7 | tazovskiy
# Processing Record 6 of Set 7 | katangli
# Processing Record 7 of Set 7 | qesarya
# Processing Record 8 of Set 7 | mogadishu
# Processing Record 9 of Set 7 | nikolskoye
# Processing Record 10 of Set 7 | richards bay
# Processing Record 11 of Set 7 | berlevag
# Processing Record 12 of Set 7 | sechura
# Processing Record 13 of Set 7 | chisec
# Processing Record 14 of Set 7 | sinop
# Processing Record 15 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 7 | dawei
# Processing Record 17 of Set 7 | abha
# Processing Record 18 of Set 7 | longyearbyen
# Processing Record 19 of Set 7 | half moon bay
# Processing Record 20 of Set 7 | cabedelo
# Processing Record 21 of Set 7 | palmer
# Processing Record 22 of Set 7 | caravelas
# Processing Record 23 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 7 | avera
# Processing Record 26 of Set 7 | katsuura
# Processing Record 27 of Set 7 | ixtapa
# Processing Record 28 of Set 7 | churumuco
# City not found. Skipping...
# Processing Record 29 of Set 7 | kupang
# Processing Record 30 of Set 7 | marzuq
# Processing Record 31 of Set 7 | betioky
# Processing Record 32 of Set 7 | ulaanbaatar
# Processing Record 33 of Set 7 | bowen
# Processing Record 34 of Set 7 | turukhansk
# Processing Record 35 of Set 7 | portland
# Processing Record 36 of Set 7 | akyab
# Processing Record 37 of Set 7 | opuwo
# Processing Record 38 of Set 7 | arona
# Processing Record 39 of Set 7 | salalah
# Processing Record 40 of Set 7 | okhotsk
# Processing Record 41 of Set 7 | dalbandin
# Processing Record 42 of Set 7 | tulun
# Processing Record 43 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 7 | antsohihy
# Processing Record 45 of Set 7 | wembley
# Processing Record 46 of Set 7 | kaeo
# Processing Record 47 of Set 7 | venezuela
# Processing Record 48 of Set 7 | leningradskiy
# Processing Record 49 of Set 7 | la asuncion
# Processing Record 50 of Set 7 | tete
# Processing Record 1 of Set 8 | souillac
# Processing Record 2 of Set 8 | hay river
# Processing Record 3 of Set 8 | kokoda
# Processing Record 4 of Set 8 | talnakh
# Processing Record 5 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 6 of Set 8 | raymond
# Processing Record 7 of Set 8 | flinders
# Processing Record 8 of Set 8 | east london
# Processing Record 9 of Set 8 | eyl
# Processing Record 10 of Set 8 | zhangjiakou
# Processing Record 11 of Set 8 | pisco
# Processing Record 12 of Set 8 | kloulklubed
# Processing Record 13 of Set 8 | tura
# Processing Record 14 of Set 8 | tiksi
# Processing Record 15 of Set 8 | tiznit
# Processing Record 16 of Set 8 | hasaki
# Processing Record 17 of Set 8 | maceio
# Processing Record 18 of Set 8 | wattegama
# Processing Record 19 of Set 8 | raga
# Processing Record 20 of Set 8 | kadirli
# Processing Record 21 of Set 8 | inirida
# Processing Record 22 of Set 8 | fukue
# Processing Record 23 of Set 8 | nuseni
# Processing Record 24 of Set 8 | alamos
# Processing Record 25 of Set 8 | mitu
# Processing Record 26 of Set 8 | scottsbluff
# Processing Record 27 of Set 8 | ostrovnoy
# Processing Record 28 of Set 8 | cabinda
# Processing Record 29 of Set 8 | cururupu
# Processing Record 30 of Set 8 | mombetsu
# Processing Record 31 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 8 | coihaique
# Processing Record 33 of Set 8 | campo grande
# Processing Record 34 of Set 8 | frontera
# Processing Record 35 of Set 8 | zharkent
# Processing Record 36 of Set 8 | tatarsk
# Processing Record 37 of Set 8 | vidim
# Processing Record 38 of Set 8 | maniitsoq
# Processing Record 39 of Set 8 | santa luzia
# Processing Record 40 of Set 8 | nipawin
# Processing Record 41 of Set 8 | wad rawah
# Processing Record 42 of Set 8 | itatiaia
# Processing Record 43 of Set 8 | kruisfontein
# Processing Record 44 of Set 8 | zarate
# Processing Record 45 of Set 8 | aklavik
# Processing Record 46 of Set 8 | vostok
# Processing Record 47 of Set 8 | kodarma
# Processing Record 48 of Set 8 | nome
# Processing Record 49 of Set 8 | genhe
# Processing Record 50 of Set 8 | morros
# Processing Record 1 of Set 9 | mao
# Processing Record 2 of Set 9 | lamu
# Processing Record 3 of Set 9 | atherton
# Processing Record 4 of Set 9 | sao francisco de assis
# Processing Record 5 of Set 9 | leshukonskoye
# Processing Record 6 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 9 | leninskoye
# Processing Record 8 of Set 9 | hudson bay
# Processing Record 9 of Set 9 | xuddur
# Processing Record 10 of Set 9 | lagoa
# Processing Record 11 of Set 9 | rognan
# Processing Record 12 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 13 of Set 9 | maraa
# Processing Record 14 of Set 9 | udachnyy
# Processing Record 15 of Set 9 | necochea
# Processing Record 16 of Set 9 | lagunas
# Processing Record 17 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 9 | leh
# Processing Record 19 of Set 9 | tongliao
# Processing Record 20 of Set 9 | myitkyina
# Processing Record 21 of Set 9 | madang
# Processing Record 22 of Set 9 | ayr
# Processing Record 23 of Set 9 | ilo
# Processing Record 24 of Set 9 | varnavino
# Processing Record 25 of Set 9 | ketchikan
# Processing Record 26 of Set 9 | bairiki
# Processing Record 27 of Set 9 | saint-georges
# Processing Record 28 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 9 | pitmoaga
# Processing Record 30 of Set 9 | redlands
# Processing Record 31 of Set 9 | laguna
# Processing Record 32 of Set 9 | filingue
# Processing Record 33 of Set 9 | tuatapere
# Processing Record 34 of Set 9 | sapulpa
# Processing Record 35 of Set 9 | baruun-urt
# Processing Record 36 of Set 9 | kathmandu
# Processing Record 37 of Set 9 | auki
# Processing Record 38 of Set 9 | hailey
# Processing Record 39 of Set 9 | bambanglipuro
# Processing Record 40 of Set 9 | uspenka
# Processing Record 41 of Set 9 | virginia beach
# Processing Record 42 of Set 9 | saurimo
# Processing Record 43 of Set 9 | batagay-alyta
# Processing Record 44 of Set 9 | awbari
# Processing Record 45 of Set 9 | detchino
# Processing Record 46 of Set 9 | kidal
# Processing Record 47 of Set 9 | nuuk
# Processing Record 48 of Set 9 | kudligi
# Processing Record 49 of Set 9 | salinopolis
# Processing Record 50 of Set 9 | vila velha
# Processing Record 1 of Set 10 | ahipara
# Processing Record 2 of Set 10 | vangaindrano
# Processing Record 3 of Set 10 | bagdarin
# Processing Record 4 of Set 10 | tres pontas
# Processing Record 5 of Set 10 | ullapool
# Processing Record 6 of Set 10 | balkhash
# Processing Record 7 of Set 10 | port macquarie
# Processing Record 8 of Set 10 | gushikawa
# Processing Record 9 of Set 10 | zelenoborsk
# Processing Record 10 of Set 10 | guerrero negro
# Processing Record 11 of Set 10 | komsomolskiy
# Processing Record 12 of Set 10 | waingapu
# Processing Record 13 of Set 10 | yuxia
# Processing Record 14 of Set 10 | vaitape
# Processing Record 15 of Set 10 | saint pete beach
# Processing Record 16 of Set 10 | gazanjyk
# Processing Record 17 of Set 10 | novi troyany
# Processing Record 18 of Set 10 | pevek
# Processing Record 19 of Set 10 | jalpan
# Processing Record 20 of Set 10 | biu
# Processing Record 21 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 10 | iralaya
# Processing Record 24 of Set 10 | korla
# Processing Record 25 of Set 10 | garden city
# Processing Record 26 of Set 10 | ceuta
# Processing Record 27 of Set 10 | gondanglegi
# Processing Record 28 of Set 10 | blessington
# Processing Record 29 of Set 10 | nyurba
# Processing Record 30 of Set 10 | erzin
# Processing Record 31 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 10 | presidencia roque saenz pena
# Processing Record 33 of Set 10 | svetlyy
# Processing Record 34 of Set 10 | canutama
# Processing Record 35 of Set 10 | baghdad
# Processing Record 36 of Set 10 | foumban
# Processing Record 37 of Set 10 | olinda
# Processing Record 38 of Set 10 | nishihara
# Processing Record 39 of Set 10 | kasra
# City not found. Skipping...
# Processing Record 40 of Set 10 | lorengau
# Processing Record 41 of Set 10 | rio gallegos
# Processing Record 42 of Set 10 | bireun
# Processing Record 43 of Set 10 | tonj
# Processing Record 44 of Set 10 | prince rupert
# Processing Record 45 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | kuala krai
# City not found. Skipping...
# Processing Record 47 of Set 10 | nusaybin
# Processing Record 48 of Set 10 | fuyu
# Processing Record 49 of Set 10 | henties bay
# Processing Record 50 of Set 10 | omsk
# Processing Record 1 of Set 11 | aguimes
# Processing Record 2 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 3 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 11 | zhanaozen
# Processing Record 5 of Set 11 | bayanday
# Processing Record 6 of Set 11 | nanortalik
# Processing Record 7 of Set 11 | suslovo
# Processing Record 8 of Set 11 | sassandra
# Processing Record 9 of Set 11 | cidreira
# Processing Record 10 of Set 11 | ajdabiya
# Processing Record 11 of Set 11 | talakan
# Processing Record 12 of Set 11 | polovinnoye
# Processing Record 13 of Set 11 | havelock
# Processing Record 14 of Set 11 | carballo
# Processing Record 15 of Set 11 | grand forks
# Processing Record 16 of Set 11 | alyangula
# Processing Record 17 of Set 11 | balkanabat
# Processing Record 18 of Set 11 | minamata
# Processing Record 19 of Set 11 | senmonorom
# City not found. Skipping...
# Processing Record 20 of Set 11 | ronse
# Processing Record 21 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 11 | porto nacional
# Processing Record 23 of Set 11 | promyshlennovskiy
# Processing Record 24 of Set 11 | kattivakkam
# Processing Record 25 of Set 11 | rocha
# Processing Record 26 of Set 11 | ginda
# Processing Record 27 of Set 11 | kharp
# Processing Record 28 of Set 11 | maria aurora
# Processing Record 29 of Set 11 | artyom
# Processing Record 30 of Set 11 | egvekinot
# Processing Record 31 of Set 11 | dasoguz
# Processing Record 32 of Set 11 | road town
# Processing Record 33 of Set 11 | roma
# Processing Record 34 of Set 11 | dzhebariki-khaya
# Processing Record 35 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 11 | ellisras
# Processing Record 37 of Set 11 | chuchkovo
# Processing Record 38 of Set 11 | ler
# Processing Record 39 of Set 11 | fuerte olimpo
# Processing Record 40 of Set 11 | pasaje
# Processing Record 41 of Set 11 | quatre cocos
# Processing Record 42 of Set 11 | masakin
# Processing Record 43 of Set 11 | prado
# Processing Record 44 of Set 11 | kashiwazaki
# Processing Record 45 of Set 11 | langsa
# Processing Record 46 of Set 11 | atagay
# Processing Record 47 of Set 11 | yeniseysk
# Processing Record 48 of Set 11 | denpasar
# Processing Record 49 of Set 11 | atar
# Processing Record 50 of Set 11 | buala
# Processing Record 1 of Set 12 | navrongo
# Processing Record 2 of Set 12 | mareeba
# Processing Record 3 of Set 12 | tarragona
# Processing Record 4 of Set 12 | kaduna
# Processing Record 5 of Set 12 | eruwa
# Processing Record 6 of Set 12 | san ramon de la nueva oran
# Processing Record 7 of Set 12 | nicoya
# Processing Record 8 of Set 12 | shimoda
# Processing Record 9 of Set 12 | vila
# Processing Record 10 of Set 12 | george
# Processing Record 11 of Set 12 | mhlume
# Processing Record 12 of Set 12 | maningrida
# Processing Record 13 of Set 12 | lumphat
# Processing Record 14 of Set 12 | juli
# Processing Record 15 of Set 12 | bo rai
# Processing Record 16 of Set 12 | saint-augustin
# Processing Record 17 of Set 12 | tharad
# Processing Record 18 of Set 12 | camocim
# Processing Record 19 of Set 12 | constitucion
# Processing Record 20 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 21 of Set 12 | teguldet
# Processing Record 22 of Set 12 | weihe
# Processing Record 23 of Set 12 | harrisonville
# Processing Record 24 of Set 12 | waipawa
# Processing Record 25 of Set 12 | namatanai
# Processing Record 26 of Set 12 | turkistan
# Processing Record 27 of Set 12 | mantua
# Processing Record 28 of Set 12 | hervey bay
# Processing Record 29 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 12 | taoudenni
# Processing Record 31 of Set 12 | muravlenko
# Processing Record 32 of Set 12 | urumqi
# Processing Record 33 of Set 12 | kroya
# Processing Record 34 of Set 12 | tommot
# Processing Record 35 of Set 12 | bay roberts
# Processing Record 36 of Set 12 | aitape
# Processing Record 37 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 12 | praia da vitoria
# Processing Record 39 of Set 12 | shagonar
# Processing Record 40 of Set 12 | adeje
# Processing Record 41 of Set 12 | mecca
# Processing Record 42 of Set 12 | makakilo city
# Processing Record 43 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 12 | antissa
# City not found. Skipping...
# Processing Record 45 of Set 12 | bijar
# Processing Record 46 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 12 | aberdeen
# Processing Record 48 of Set 12 | gigmoto
# Processing Record 49 of Set 12 | gilgit
# Processing Record 50 of Set 12 | bad lauterberg
# Processing Record 1 of Set 13 | bay saint louis
# Processing Record 2 of Set 13 | namibe
# Processing Record 3 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 13 | oum hadjer
# Processing Record 5 of Set 13 | colares
# Processing Record 6 of Set 13 | sosva
# Processing Record 7 of Set 13 | kaseda
# Processing Record 8 of Set 13 | khandyga
# Processing Record 9 of Set 13 | esperance
# Processing Record 10 of Set 13 | piranhas
# Processing Record 11 of Set 13 | tokur
# Processing Record 12 of Set 13 | kennett
# Processing Record 13 of Set 13 | pringsewu
# Processing Record 14 of Set 13 | khoy
# Processing Record 15 of Set 13 | ovre ardal
# Processing Record 16 of Set 13 | port-gentil
# Processing Record 17 of Set 13 | kilembe
# Processing Record 18 of Set 13 | kareli
# Processing Record 19 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 13 | wanaka
# Processing Record 21 of Set 13 | matongo
# Processing Record 22 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 23 of Set 13 | manokwari
# Processing Record 24 of Set 13 | aykhal
# Processing Record 25 of Set 13 | vega de alatorre
# Processing Record 26 of Set 13 | ialibu
# Processing Record 27 of Set 13 | erzurum
# Processing Record 28 of Set 13 | bordighera
# Processing Record 29 of Set 13 | krasnoarmeysk
# Processing Record 30 of Set 13 | hobyo
# Processing Record 31 of Set 13 | artesia
# Processing Record 32 of Set 13 | alofi
# Processing Record 33 of Set 13 | mahbubnagar
# Processing Record 34 of Set 13 | vardo
# Processing Record 35 of Set 13 | eresos
# Processing Record 36 of Set 13 | puerto del rosario
# Processing Record 37 of Set 13 | el alto
# Processing Record 38 of Set 13 | palu
# Processing Record 39 of Set 13 | mount isa
# Processing Record 40 of Set 13 | zhigansk
# Processing Record 41 of Set 13 | miramar
# Processing Record 42 of Set 13 | altay
# Processing Record 43 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 13 | mandalgovi
# Processing Record 46 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 47 of Set 13 | pilar
# Processing Record 48 of Set 13 | bellingham
# Processing Record 49 of Set 13 | buin
# Processing Record 50 of Set 13 | auch
# Processing Record 1 of Set 14 | sao felix do xingu
# Processing Record 2 of Set 14 | thessalon
# Processing Record 3 of Set 14 | port lincoln
# Processing Record 4 of Set 14 | la troncal
# Processing Record 5 of Set 14 | ushtobe
# Processing Record 6 of Set 14 | rab
# City not found. Skipping...
# Processing Record 7 of Set 14 | santa cruz
# Processing Record 8 of Set 14 | belaya gora
# Processing Record 9 of Set 14 | smithers
# Processing Record 10 of Set 14 | kinablangan
# Processing Record 11 of Set 14 | tilichiki
# Processing Record 12 of Set 14 | guaratingueta
# Processing Record 13 of Set 14 | sakakah
# Processing Record 14 of Set 14 | marti
# Processing Record 15 of Set 14 | safita
# Processing Record 16 of Set 14 | rundu
# Processing Record 17 of Set 14 | rawatsar
# Processing Record 18 of Set 14 | harnosand
# Processing Record 19 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 14 | aichach
# Processing Record 21 of Set 14 | jasper
# Processing Record 22 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 14 | puno
# Processing Record 24 of Set 14 | waddan
# Processing Record 25 of Set 14 | port hardy
# Processing Record 26 of Set 14 | hamilton
# Processing Record 27 of Set 14 | vestmanna
# Processing Record 28 of Set 14 | kamaishi
# Processing Record 29 of Set 14 | puksoozero
# Processing Record 30 of Set 14 | dyurtyuli
# Processing Record 31 of Set 14 | blois
# Processing Record 32 of Set 14 | hauterive
# Processing Record 33 of Set 14 | berdigestyakh
# Processing Record 34 of Set 14 | kampene
# Processing Record 35 of Set 14 | plyussa
# Processing Record 36 of Set 14 | padang
# Processing Record 37 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 38 of Set 14 | rasulnagar
# Processing Record 39 of Set 14 | alvorada
# Processing Record 40 of Set 14 | york
# Processing Record 41 of Set 14 | guarapari
# Processing Record 42 of Set 14 | lakatoro
# Processing Record 43 of Set 14 | mayo
# Processing Record 44 of Set 14 | san cristobal
# Processing Record 45 of Set 14 | tongren
# Processing Record 46 of Set 14 | bouza
# Processing Record 47 of Set 14 | magdagachi
# Processing Record 48 of Set 14 | uttaradit
# Processing Record 49 of Set 14 | kitgum
# Processing Record 50 of Set 14 | kysyl-syr
# Processing Record 1 of Set 15 | slonim
# Processing Record 2 of Set 15 | mount gambier
# Processing Record 3 of Set 15 | xapuri
# Processing Record 4 of Set 15 | ayna
# Processing Record 5 of Set 15 | yaan
# Processing Record 6 of Set 15 | conceicao da barra
# Processing Record 7 of Set 15 | cimarron hills
# Processing Record 8 of Set 15 | vikhorevka
# Processing Record 9 of Set 15 | uyuni
# Processing Record 10 of Set 15 | mackay
# Processing Record 11 of Set 15 | jumla
# Processing Record 12 of Set 15 | nago
# Processing Record 13 of Set 15 | sambava
# Processing Record 14 of Set 15 | gao
# Processing Record 15 of Set 15 | tanabi
# Processing Record 16 of Set 15 | burns lake
# Processing Record 17 of Set 15 | ilhabela
# Processing Record 18 of Set 15 | karpathos
# Processing Record 19 of Set 15 | lavumisa
# Processing Record 20 of Set 15 | semirom
# Processing Record 21 of Set 15 | groningen
# Processing Record 22 of Set 15 | araceli
# Processing Record 23 of Set 15 | lensk
# Processing Record 24 of Set 15 | juneau
# Processing Record 25 of Set 15 | puerto escondido
# Processing Record 26 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 15 | adrar
# Processing Record 28 of Set 15 | kieta
# Processing Record 29 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 30 of Set 15 | praya
# Processing Record 31 of Set 15 | resistencia
# Processing Record 32 of Set 15 | shelburne
# Processing Record 33 of Set 15 | linguere
# Processing Record 34 of Set 15 | zemio
# Processing Record 35 of Set 15 | soyo
# Processing Record 36 of Set 15 | huarmey
# Processing Record 37 of Set 15 | chimore
# Processing Record 38 of Set 15 | dunedin
# Processing Record 39 of Set 15 | tucuman
# Processing Record 40 of Set 15 | malanje
# Processing Record 41 of Set 15 | xining
# Processing Record 42 of Set 15 | chignautla
# Processing Record 43 of Set 15 | nador
# Processing Record 44 of Set 15 | namie
# Processing Record 45 of Set 15 | perundurai
# Processing Record 46 of Set 15 | toora-khem
# Processing Record 47 of Set 15 | kenai
# Processing Record 48 of Set 15 | anage
# Processing Record 49 of Set 15 | svetlogorsk
# Processing Record 50 of Set 15 | jalu
# Processing Record 1 of Set 16 | sao borja
# Processing Record 2 of Set 16 | xiuyan
# Processing Record 3 of Set 16 | beipiao
# Processing Record 4 of Set 16 | kodinar
# Processing Record 5 of Set 16 | ploemeur
# Processing Record 6 of Set 16 | abbiategrasso
# Processing Record 7 of Set 16 | pimentel
# Processing Record 8 of Set 16 | benjamin constant
# Processing Record 9 of Set 16 | fare
# Processing Record 10 of Set 16 | singaraja
# Processing Record 11 of Set 16 | cortes
# Processing Record 12 of Set 16 | shenzhen
# Processing Record 13 of Set 16 | daru
# Processing Record 14 of Set 16 | guangyuan
# Processing Record 15 of Set 16 | comodoro rivadavia
# Processing Record 16 of Set 16 | mhlambanyatsi
# Processing Record 17 of Set 16 | dogbo
# Processing Record 18 of Set 16 | vao
# Processing Record 19 of Set 16 | chatham
# Processing Record 20 of Set 16 | suileng
# Processing Record 21 of Set 16 | codajas
# Processing Record 22 of Set 16 | aksarka
# Processing Record 23 of Set 16 | jeannette
# Processing Record 24 of Set 16 | kirakira
# Processing Record 25 of Set 16 | sinnar
# Processing Record 26 of Set 16 | nyanguge
# Processing Record 27 of Set 16 | wenatchee
# Processing Record 28 of Set 16 | fortuna
# Processing Record 29 of Set 16 | christchurch
# Processing Record 30 of Set 16 | chagda
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(5)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro -24.7911  -50.0119     68.70        82          69
# 1  Puerto Ayora  -0.7393  -90.3518     80.56        80          56
# 2      Nanakuli  21.3906 -158.1547     73.62        77          40
# 3        Atuona  -9.8000 -139.0333     78.78        77          36
# 4        Albany  42.6001  -73.9662     77.95        51          98
#
#    Wind Speed Country Current Description                 Date
# 0        8.63      BR       broken clouds  2022-04-14 15:54:17
# 1       10.47      EC       broken clouds  2022-04-14 15:54:17
# 2        5.75      US    scattered clouds  2022-04-14 15:54:18
# 3       15.64      PF          light rain  2022-04-14 15:54:18
# 4        1.01      US     overcast clouds  2022-04-14 15:52:46

# %%
# Reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro      BR -24.7911  -50.0119     68.70        82          69
# 1  Puerto Ayora      EC  -0.7393  -90.3518     80.56        80          56
# 2      Nanakuli      US  21.3906 -158.1547     73.62        77          40
# 3        Atuona      PF  -9.8000 -139.0333     78.78        77          36
# 4        Albany      US  42.6001  -73.9662     77.95        51          98
# 5      Progreso      MX  21.2833  -89.6667     88.11        52          77
# 6         Kapaa      US  22.0752 -159.3190     73.11        84          81
# 7     Bathsheba      BB  13.2167  -59.5167     86.61        62          75
# 8   Port Alfred      ZA -33.5906   26.8910     65.17        90         100
# 9     Cocobeach      GA   1.0002    9.5823     79.36        81          98
#
#    Wind Speed Current Description
# 0        8.63       broken clouds
# 1       10.47       broken clouds
# 2        5.75    scattered clouds
# 3       15.64          light rain
# 4        1.01     overcast clouds
# 5        9.73       broken clouds
# 6        1.99       broken clouds
# 7       21.85       broken clouds
# 8        1.99     overcast clouds
# 9        4.65     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
